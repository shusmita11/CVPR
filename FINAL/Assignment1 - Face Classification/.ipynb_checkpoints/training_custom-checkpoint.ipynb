# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
path = "images"
classes = ['Ahsam', 'Maruf', 'Saiba', 'Aziz']
classLabel = {cls: idx for idx, cls in enumerate(classes)}
max_images_per_class = 350
image_size = 128

# %%
data = []
for cls in classes:
    class_dir = os.path.join(path, cls)
    count = 0
    for img_name in tqdm(os.listdir(class_dir), desc=f"Loading {cls}"):
        if count >= max_images_per_class:
            break
        img_path = os.path.join(class_dir, img_name)
        img = cv2.imread(img_path)
        if img is None:
            continue
        img = cv2.resize(img, (image_size, image_size))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = img / 255.0
        data.append((img, classLabel[cls]))
        count += 1

print(f"Total samples: {len(data)}")
# Out:
# Loading Ahsam: 100%|█████████████████████████████████████████████████████████████████| 350/350 [00:05<00:00, 59.57it/s]
# Loading Maruf: 100%|█████████████████████████████████████████████████████████████████| 350/350 [00:05<00:00, 59.24it/s]
# Loading Saiba: 100%|█████████████████████████████████████████████████████████████████| 350/350 [00:05<00:00, 59.83it/s]
# Loading Aziz: 100%|██████████████████████████████████████████████████████████████████| 350/350 [00:06<00:00, 55.37it/s]
# Total samples: 1400

# %%
plt.figure(figsize=(10,10))
i = 0
for r in range(10):
    for c in range(10):
        plt.subplot(10, 12, i + 1)
        plt.imshow(data[i][0])
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(data[i][1])
        i += 1
plt.show()

# %%
np.random.shuffle(data)

# %%
plt.figure(figsize=(10,10))
i = 0
for r in range(10):
    for c in range(10):
        plt.subplot(10, 12, i + 1)
        plt.imshow(data[i][0])
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(data[i][1])
        i += 1
plt.show()

# %%
X, y = zip(*data)
X = np.array(X, dtype=np.float32)
y = np.array(y)
y_cat = to_categorical(y, num_classes=len(classes))

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y_cat, test_size=0.2, random_state=42)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
val_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32)

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(image_size, image_size, 3)),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(128, activation='relu'),
    Dense(len(classes), activation='softmax')
])
# Out:
# C:\Users\Asus\anaconda3\envs\tf2env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 126, 126, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 61, 61, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       6,422,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,550,340 (24.99 MB)
#  Trainable params: 6,549,892 (24.99 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50
)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 626ms/step - accuracy: 0.9954 - loss: 0.0736 - val_accuracy: 0.9821 - val_loss: 0.1905
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 643ms/step - accuracy: 0.9955 - loss: 0.0971 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 636ms/step - accuracy: 0.9961 - loss: 0.0199 - val_accuracy: 0.7643 - val_loss: 8.7307
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 643ms/step - accuracy: 0.9977 - loss: 0.1426 - val_accuracy: 0.9964 - val_loss: 0.0026
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 626ms/step - accuracy: 0.9964 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 630ms/step - accuracy: 0.9991 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 625ms/step - accuracy: 0.9982 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 613ms/step - accuracy: 0.9954 - loss: 0.1245 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 623ms/step - accuracy: 0.9971 - loss: 0.0449 - val_accuracy: 0.5429 - val_loss: 65.0261
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 611ms/step - accuracy: 0.9969 - loss: 0.0082 - val_accuracy: 0.4964 - val_loss: 255.0166
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 620ms/step - accuracy: 0.9978 - loss: 0.0242 - val_accuracy: 0.5357 - val_loss: 116.0746
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 632ms/step - accuracy: 0.9944 - loss: 0.1017 - val_accuracy: 0.9893 - val_loss: 0.0945
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 642ms/step - accuracy: 0.9943 - loss: 0.1349 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 631ms/step - accuracy: 0.9996 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 638ms/step - accuracy: 0.9979 - loss: 0.0262 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 634ms/step - accuracy: 0.9989 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 628ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 630ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 629ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 620ms/step - accuracy: 0.9992 - loss: 0.0172 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 627ms/step - accuracy: 0.9963 - loss: 0.2733 - val_accuracy: 0.9964 - val_loss: 0.0575
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 619ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 633ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 631ms/step - accuracy: 0.9997 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 41s 624ms/step - accuracy: 0.9986 - loss: 0.0072 - val_accuracy: 0.7571 - val_loss: 46.0095
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 641ms/step - accuracy: 0.9944 - loss: 0.3114 - val_accuracy: 0.2679 - val_loss: 600.9639
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 655ms/step - accuracy: 0.9993 - loss: 0.0240 - val_accuracy: 0.4929 - val_loss: 134.6004
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 634ms/step - accuracy: 0.9965 - loss: 0.0716 - val_accuracy: 0.7750 - val_loss: 20.0279
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 643ms/step - accuracy: 0.9973 - loss: 0.0801 - val_accuracy: 0.7500 - val_loss: 42.6751
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 616ms/step - accuracy: 0.9947 - loss: 0.3083 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 628ms/step - accuracy: 1.0000 - loss: 9.0912e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 622ms/step - accuracy: 1.0000 - loss: 7.5346e-05 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 632ms/step - accuracy: 0.9987 - loss: 0.0517 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 649ms/step - accuracy: 0.9869 - loss: 0.3327 - val_accuracy: 0.9250 - val_loss: 2.3923
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 636ms/step - accuracy: 0.9953 - loss: 0.3542 - val_accuracy: 0.5536 - val_loss: 104.8493
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 627ms/step - accuracy: 0.9968 - loss: 0.0237 - val_accuracy: 0.7571 - val_loss: 43.8335
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 635ms/step - accuracy: 0.9997 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 625ms/step - accuracy: 0.9984 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 635ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 642ms/step - accuracy: 0.9939 - loss: 0.2478 - val_accuracy: 0.9893 - val_loss: 0.0586
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 625ms/step - accuracy: 0.9982 - loss: 0.0221 - val_accuracy: 0.9607 - val_loss: 1.4714
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 641ms/step - accuracy: 0.9982 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 610ms/step - accuracy: 0.9991 - loss: 0.0666 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 613ms/step - accuracy: 1.0000 - loss: 3.7662e-04 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 639ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 621ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 638ms/step - accuracy: 1.0000 - loss: 4.7654e-05 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 619ms/step - accuracy: 1.0000 - loss: 2.2114e-11 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 624ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 603ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
model.save("faceRecoginition_custom.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
